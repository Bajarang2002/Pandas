# %%
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch
# 0  female        group B           bachelor's degree      standard  \
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
# Filter by using dataframe

r1 =df [df['race/ethnicity']== 'group C']
r1.head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch
# 1   female        group C                some college      standard  \
# 4     male        group C                some college      standard
# 10    male        group C          associate's degree      standard
# 15  female        group C            some high school      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 19  female        group C          associate's degree  free/reduced
# 23  female        group C            some high school      standard
# 27  female        group C           bachelor's degree      standard
# 28    male        group C                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 1                completed          69             90             88
# 4                     none          76             78             75
# ...

# %%
r2=df [(df['race/ethnicity']== 'group C')&(df['test preparation course'] =='completed')]
r2.head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch
# 1    female        group C                some college      standard  \
# 18     male        group C             master's degree  free/reduced
# 49     male        group C                 high school      standard
# 54   female        group C            some high school  free/reduced
# 93     male        group C          associate's degree  free/reduced
# 95     male        group C          associate's degree  free/reduced
# 104    male        group C                some college      standard
# 120  female        group C           bachelor's degree      standard
# 122  female        group C                some college      standard
# 131    male        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          69             90             88
# ...

# %%
avg_math_score =df['math score'].mean()
avg_math_score
# Out:
# 66.089

# %%
res = df[(df['gender']=='female')&(df['math score']>df['math score'].mean())]
res.head(10)
# Out:
#     gender race/ethnicity parental level of education     lunch
# 0   female        group B           bachelor's degree  standard  \
# 1   female        group C                some college  standard
# 2   female        group B             master's degree  standard
# 5   female        group B          associate's degree  standard
# 6   female        group B                some college  standard
# 15  female        group C            some high school  standard
# 23  female        group C            some high school  standard
# 27  female        group C           bachelor's degree  standard
# 30  female        group D                some college  standard
# 36  female        group D          associate's degree  standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 1                completed          69             90             88
# ...

# %%
avg_read_score = df["reading score"].mean()
avg_read_score
# Out:
# 69.169

# %%
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch
# 0  female        group B           bachelor's degree      standard  \
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
avg_read_score = df["reading score"].mean()
avg_read_score
# Out:
# 69.169

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
res =df.loc[ (df['math score']>df['math score'].mean()) & (df['reading score']<df['reading score'].mean())]
res.head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch
# 26     male        group B                some college      standard  \
# 27   female        group C           bachelor's degree      standard
# 51     male        group E          associate's degree  free/reduced
# 65     male        group B            some high school      standard
# 83     male        group E          associate's degree      standard
# 100    male        group B                some college      standard
# 109  female        group B            some high school      standard
# 126    male        group B            some high school      standard
# 137    male        group E                 high school      standard
# 139    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 26                     none          69             54             55
# ...

# %%
res1 =df.sort_values(by ='writing score')
res1.head(20)
# Out:
#      gender race/ethnicity parental level of education         lunch
# 59   female        group C            some high school  free/reduced  \
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 338  female        group B            some high school  free/reduced
# 896    male        group B                 high school  free/reduced
# 211    male        group C                some college  free/reduced
# 17   female        group B            some high school  free/reduced
# 601  female        group C                 high school      standard
# 363  female        group D            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ...

# %%
# sort function
res2 = df.sort_values(by ='reading score',ascending =False)
res2.head(30)
# Out:
#      gender race/ethnicity parental level of education         lunch
# 546  female        group A            some high school      standard  \
# 970  female        group D           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 566  female        group E           bachelor's degree  free/reduced
# 712  female        group D                some college      standard
# 179  female        group D            some high school      standard
# 886  female        group E          associate's degree      standard
# 381    male        group C          associate's degree      standard
# 106  female        group D             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
# 458  female        group E           bachelor's degree      standard
# 957  female        group D             master's degree      standard
# ...

# %%
res2 = df.sort_values(by =['reading score','writing score'],ascending =False)
res2.head(30)
# Out:
#      gender race/ethnicity parental level of education         lunch
# 106  female        group D             master's degree      standard  \
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 458  female        group E           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 903  female        group D           bachelor's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
# 594  female        group C           bachelor's degree      standard
# 712  female        group D                some college      standard
# ...

# %%
res3 = df.groupby('parental level of education')[['math score','reading score']].sum()
res3.head(10)
# Out:
#                              math score  reading score
# parental level of education
# associate's degree                15070          15746
# bachelor's degree                  8188           8614
# high school                       12179          12682
# master's degree                    4115           4447
# some college                      15171          15698
# some high school                  11366          11982

# %%
res3 = df.groupby(['gender','race/ethnicity'])[['writing score','reading score']].sum()
res3.head(10)
# Out:
#                        writing score  reading score
# gender race/ethnicity
# female group A                  2443           2484
#        group B                  7285           7392
#        group C                 12920          12950
#        group D                  9678           9552
#        group E                  5212           5233
# male   group A                  3135           3272
#        group B                  5179           5405
#        group C                  8717           9094
#        group D                  8700           8796
#        group E                  4785           4991

# %%
res3 = df[(df['parental level of education']=='masters degree')|(df['gender']=='male')]
res3.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch
# 3    male        group A          associate's degree  free/reduced  \
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 10   male        group C          associate's degree      standard
# 11   male        group D          associate's degree      standard
# 13   male        group A                some college      standard
# 16   male        group C                 high school      standard
# 18   male        group C             master's degree  free/reduced
# 20   male        group D                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 4                     none          76             78             75
# ...
