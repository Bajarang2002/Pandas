# %%
import pandas as pd
data = {'C_ID':[2,4,6,7,8],'State':['Maharastra','Karnatak','Keral','UP','Telangana']}
df2 = pd.DataFrame(data)
df2
# Out:
#    C_ID       State
# 0     2  Maharastra
# 1     4    Karnatak
# 2     6       Keral
# 3     7          UP
# 4     8   Telangana

# %%
import pandas as pd
d1={'C_ID':[1,2,3,4,5,6],'Product':['oven','Wasging machine','Mixer','Mobail','Television','Freeze']}
df1=pd.DataFrame(d1)
df1.head()
# Out:
#    C_ID          Product
# 0     1             oven
# 1     2  Wasging machine
# 2     3            Mixer
# 3     4           Mobail
# 4     5       Television

# %%
df_merge = df1.merge(df2)
df_merge
# Out:
#    C_ID          Product       State
# 0     2  Wasging machine  Maharastra
# 1     4           Mobail    Karnatak
# 2     6           Freeze       Keral

# %%
df_inner = df1.merge(df2,on ='C_ID',how ='inner')
df_inner
# Out:
#    C_ID          Product       State
# 0     2  Wasging machine  Maharastra
# 1     4           Mobail    Karnatak
# 2     6           Freeze       Keral

# %%
df_outer = df1.merge(df2,on ='C_ID',how ='outer')
df_outer
# Out:
#    C_ID          Product       State
# 0     1             oven         NaN
# 1     2  Wasging machine  Maharastra
# 2     3            Mixer         NaN
# 3     4           Mobail    Karnatak
# 4     5       Television         NaN
# 5     6           Freeze       Keral
# 6     7              NaN          UP
# 7     8              NaN   Telangana

# %%
df_left = df1.merge(df2,on ='C_ID',how ='left')
df_left
# Out:
#    C_ID          Product       State
# 0     1             oven         NaN
# 1     2  Wasging machine  Maharastra
# 2     3            Mixer         NaN
# 3     4           Mobail    Karnatak
# 4     5       Television         NaN
# 5     6           Freeze       Keral

# %%
df_right = df1.merge(df2,on ='C_ID',how ='right')
df_right
# Out:
#    C_ID          Product       State
# 0     2  Wasging machine  Maharastra
# 1     4           Mobail    Karnatak
# 2     6           Freeze       Keral
# 3     7              NaN          UP
# 4     8              NaN   Telangana

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Top100moststreamed.csv")
df.head(10)
# Out:
#                     title           artist                  top genre  year
# 0         Blinding Lights       The Weeknd  canadian contemporary r&b  2020  \
# 1        Watermelon Sugar     Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)         24kGoldn                   cali rap  2021
# 3       Someone You Loved    Lewis Capaldi                        pop  2019
# 4                 Perfect       Ed Sheeran                        pop  2017
# 5                Believer  Imagine Dragons                modern rock  2017
# 6    lovely (with Khalid)    Billie Eilish                 electropop  2018
# 7                 Circles      Post Malone                    dfw rap  2019
# 8            Shape of You       Ed Sheeran                        pop  2017
# 9                Memories         Maroon 5                        pop  2021
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance
# ...

# %%
top5 =df.iloc[:5,:]
next5 = df.iloc[5:10,:]
print(top5)
print(next5)
# Out:
#                     title         artist                  top genre  year
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020  \
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance
# 0               171      73            51           -6         9       33  \
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity
# ...

# %%
# Append
res_append = top5.append(next5)
res_append.shape

# %%
res_append.head(10)

# %%
# concat

df_concat =pd.concat([top5,next5])
df_concat.head(15)
# Out:
#                      title            artist                  top genre  year
# 0          Blinding Lights        The Weeknd  canadian contemporary r&b  2020  \
# 1         Watermelon Sugar      Harry Styles                        pop  2019
# 2   Mood (feat. iann dior)          24kGoldn                   cali rap  2021
# 3        Someone You Loved     Lewis Capaldi                        pop  2019
# 4                  Perfect        Ed Sheeran                        pop  2017
# 5                 Believer   Imagine Dragons                modern rock  2017
# 6     lovely (with Khalid)     Billie Eilish                 electropop  2018
# 7                  Circles       Post Malone                    dfw rap  2019
# 8             Shape of You        Ed Sheeran                        pop  2017
# 9                 Memories          Maroon 5                        pop  2021
# 10                  Closer  The Chainsmokers                  dance pop  2016
#
# ...

# %%
df_concat.columns
# Out:
# Index(['title', 'artist', 'top genre', 'year', 'beats.per.minute', 'energy',
#        'danceability', 'loudness.dB', 'liveness', 'valance', 'length',
#        'acousticness', 'speechiness', 'popularity'],
#       dtype='object')

# %%
df_concat =pd.concat([top5,next5],axis =1)
df_concat.head()
# Out:
#                     title         artist                  top genre    year
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020.0  \
# 1        Watermelon Sugar   Harry Styles                        pop  2019.0
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021.0
# 3       Someone You Loved  Lewis Capaldi                        pop  2019.0
# 4                 Perfect     Ed Sheeran                        pop  2017.0
#
#    beats.per.minute  energy  danceability  loudness.dB liveness valance  ...
# 0             171.0    73.0          51.0         -6.0      9.0    33.0  ...  \
# 1              95.0    82.0          55.0         -4.0     34.0    56.0  ...
# 2              91.0    72.0          70.0         -4.0     32.0    73.0  ...
# 3             110.0    41.0          50.0         -6.0     11.0    45.0  ...
# 4              95.0    45.0          60.0         -6.0     11.0    17.0  ...
#
# ...

# %%
df_top =df.iloc[:,:5]
df_next =df.iloc[:,5:10]
print(df_top)
print(df_next)
# Out:
#                                   title         artist
# 0                       Blinding Lights     The Weeknd  \
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute
# 0   canadian contemporary r&b  2020               171
# 1                         pop  2019                95
# 2                    cali rap  2021                91
# 3                         pop  2019               110
# ...

# %%
# Join
df_join = df_top.join(df_next)
df_join
# Out:
#                                   title         artist
# 0                       Blinding Lights     The Weeknd  \
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability
# 0   canadian contemporary r&b  2020               171      73            51  \
# 1                         pop  2019                95      82            55
# ...

# %%
# joining based on index
df1 = pd.DataFrame({'key':['K0','K1','K2','K3','K4','K5','K6'],
                   'A':['A0','A1','A2','A3','A4','A5','A6']})
df1
# Out:
#   key   A
# 0  K0  A0
# 1  K1  A1
# 2  K2  A2
# 3  K3  A3
# 4  K4  A4
# 5  K5  A5
# 6  K6  A6

# %%
df2 = pd.DataFrame({'key':['K0','K1','K2'],
                   'B':['B0','B1','B2']})
df2
# Out:
#   key   B
# 0  K0  B0
# 1  K1  B1
# 2  K2  B2

# %%
df_join1=df1.join(df2,lsuffix='_1',rsuffix='_2')
print(df_join1)
# Out:
#   key_1   A key_2    B
# 0    K0  A0    K1   B1
# 1    K1  A1    K2   B2
# 2    K2  A2    K3   B3
# 3    K3  A3   NaN  NaN
# 4    K4  A4   NaN  NaN
# 5    K5  A5   NaN  NaN
# 6    K6  A6   NaN  NaN

# %%
df1 =df1.set_index('key')
df1
# Out:
#       A
# key
# K0   A0
# K1   A1
# K2   A2
# K3   A3
# K4   A4
# K5   A5
# K6   A6

# %%
df2=df2.set_index('key')
df2
# Out:
#       B
# key
# K1   B1
# K2   B2
# K3   B3

# %%
df_join2 = df1.join(df2)
df_join2
# Out:
#       A    B
# key
# K0   A0  NaN
# K1   A1   B1
# K2   A2   B2
# K3   A3   B3
# K4   A4  NaN
# K5   A5  NaN
# K6   A6  NaN
