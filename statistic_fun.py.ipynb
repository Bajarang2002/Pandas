# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Top100moststreamed.csv")
df.head(10)
# Out:
#                     title           artist                  top genre  year
# 0         Blinding Lights       The Weeknd  canadian contemporary r&b  2020  \
# 1        Watermelon Sugar     Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)         24kGoldn                   cali rap  2021
# 3       Someone You Loved    Lewis Capaldi                        pop  2019
# 4                 Perfect       Ed Sheeran                        pop  2017
# 5                Believer  Imagine Dragons                modern rock  2017
# 6    lovely (with Khalid)    Billie Eilish                 electropop  2018
# 7                 Circles      Post Malone                    dfw rap  2019
# 8            Shape of You       Ed Sheeran                        pop  2017
# 9                Memories         Maroon 5                        pop  2021
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance
# ...

# %%
df[['energy','liveness']].describe()
# Out:
#            energy    liveness
# count  100.000000  100.000000
# mean    62.680000   16.860000
# std     16.491737   12.972403
# min     11.000000    3.000000
# 25%     52.000000   10.000000
# 50%     64.500000   12.000000
# 75%     76.000000   17.250000
# max     92.000000   79.000000

# %%
r1 = df.groupby('year')[['energy','liveness']].sum()
r1
# Out:
#       energy  liveness
# year
# 1975      40        30
# 1995      90        19
# 2004      91        10
# 2008      46        11
# 2012     241       103
# 2013     229        52
# 2014     338       103
# 2015     846       203
# 2016    1019       259
# 2017     776       163
# 2018    1208       342
# 2019     935       282
# 2020     221        29
# 2021     188        80

# %%
r2 =df[df['top genre']=='pop']
print(r2.shape)
r2['popularity'].sum()
# Out:
# (11, 14)
# 899

# %%
r3 = df.groupby('year')[['energy','liveness']].sum()
r3
# Out:
#       energy  liveness
# year
# 1975      40        30
# 1995      90        19
# 2004      91        10
# 2008      46        11
# 2012     241       103
# 2013     229        52
# 2014     338       103
# 2015     846       203
# 2016    1019       259
# 2017     776       163
# 2018    1208       342
# 2019     935       282
# 2020     221        29
# 2021     188        80

# %%
r4 =df[df['artist']=='pop malone']
print(r4.shape)
r4['loudness.dB'].min()
# Out:
# (0, 14)
# nan

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Top100moststreamed.csv")
df.head(10)
# Out:
#                     title           artist                  top genre  year
# 0         Blinding Lights       The Weeknd  canadian contemporary r&b  2020  \
# 1        Watermelon Sugar     Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)         24kGoldn                   cali rap  2021
# 3       Someone You Loved    Lewis Capaldi                        pop  2019
# 4                 Perfect       Ed Sheeran                        pop  2017
# 5                Believer  Imagine Dragons                modern rock  2017
# 6    lovely (with Khalid)    Billie Eilish                 electropop  2018
# 7                 Circles      Post Malone                    dfw rap  2019
# 8            Shape of You       Ed Sheeran                        pop  2017
# 9                Memories         Maroon 5                        pop  2021
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance
# ...

# %%
r4 = df.groupby('artist')['danceability'].min()
r4.head()
# Out:
# artist
# 24kGoldn               70
# 5 Seconds of Summer    60
# Alan Walker            59
# Ariana Grande          72
# Avicii                 53
# Name: danceability, dtype: int64

# %%
r4 =df[df['artist']=='Ed Sheeran']
r4['acousticness'].max()
# Out:
# 61

# %%
r5 = df.groupby('top genre')[['length','acousticness']].max()
r5
# Out:
#                            length  acousticness
# top genre
# acoustic pop                  242            60
# alternative rock              223             0
# australian dance              212             5
# australian pop                209            69
# beatlesque                    259             0
# boy band                      203             2
# brostep                       214            19
# cali rap                      141            17
# canadian contemporary r&b     242            14
# canadian hip hop              199             3
# canadian pop                  234            84
# chicago rap                   240            35
# classic rock                  354            27
# conscious hip hop             177             0
# dance pop                     270            64
# danish pop                    237            29
# detroit hip hop               321             1
# dfw rap                       231            56
# ...

# %%
r6 =df[df['year']>=2017]
r6['valance'].var()
# Out:
# 448.1988120195667

# %%
df[['energy','liveness']].std()
# Out:
# energy      16.491737
# liveness    12.972403
# dtype: float64

# %%
r6 =df[df['year']>=2015]
r7 = r6.groupby('year')['popularity'].std()
r7
# Out:
# year
# 2015     5.091471
# 2016     8.007288
# 2017     2.386833
# 2018     6.160144
# 2019     5.504165
# 2020     5.131601
# 2021    11.930353
# Name: popularity, dtype: float64

# %%
r6 =df[df['year']==2018]
r7 =r6['title'][r6['artist']=='Post Malone'].count()
r7
# Out:
# 4

# %%
r7 = df.groupby('top genre')['title'].count()
r7
# Out:
# top genre
# acoustic pop                  1
# alternative rock              1
# australian dance              1
# australian pop                1
# beatlesque                    1
# boy band                      1
# brostep                       1
# cali rap                      1
# canadian contemporary r&b     4
# canadian hip hop              2
# canadian pop                  6
# chicago rap                   1
# classic rock                  1
# conscious hip hop             1
# dance pop                    28
# danish pop                    1
# detroit hip hop               1
# dfw rap                       7
# electro house                 1
# electropop                    4
# emo rap                       2
# folk-pop                      2
# gangster rap                  1
# irish singer-songwriter       1
# latin                         2
# lgbtq+ hip hop                1
# melodic rap                   3
# modern rock                   6
# neo soul                      1
# ...

# %%
df[['valance','length','energy']].mean()
# Out:
# valance     49.97
# length     214.53
# energy      62.68
# dtype: float64

# %%
r7 = df.groupby('artist')[['popularity','energy','danceability']].mean()
r7.head()
# Out:
#                      popularity  energy  danceability
# artist
# 24kGoldn                   88.0    72.0          70.0
# 5 Seconds of Summer        80.0    85.0          60.0
# Alan Walker                72.0    65.0          59.0
# Ariana Grande              83.0    48.5          75.0
# Avicii                     84.0    78.0          53.0

# %%
df['liveness'].median()
# Out:
# 12.0

# %%
r7 = df.groupby('year')[['popularity','energy','speechiness']].median()
r7.head()
# Out:
#       popularity  energy  speechiness
# year
# 1975        81.0    40.0          5.0
# 1995        77.0    90.0          4.0
# 2004        81.0    91.0          7.0
# 2008        80.0    46.0          5.0
# 2012        80.0    78.0          6.0
